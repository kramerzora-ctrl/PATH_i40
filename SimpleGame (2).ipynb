# %%
from dataclasses import dataclass
from typing import Optional
import random

# %% [markdown]
# ### Simple Routing with discrete congestion cost pricing

# %%
# Two routes
routes = {
    'S98': {'cost': 7, 'capacity': 5, 'trucks': 0},
    'I25': {'cost': 8, 'capacity': 5, 'trucks': 0}
}

# 30 trucks
total_cost = 0

for truck_num in range(1, 20):
    
    # Try each route
    options = []
    for name, route in routes.items():
        cost = route['cost']
        
        # Congestion penalties
        if route['trucks'] >= route['capacity'] * 4:
            cost += 50  
            status = "Critical"
        elif route['trucks'] >= route['capacity']*2:
            cost += 25  
            status = "FULL"
        elif route['trucks'] > route['capacity']:
            cost += 10  # Regular congestion penalty
            status = "Congested"
        elif route['trucks'] <= route['capacity']:
            cost += 0  # Regular congestion penalty
            status = "At/ less than Capacity"
        else:
            status = f"{route['trucks']}/{route['capacity']}"
        
        options.append({
            'name': name,
            'route': route,
            'cost': cost,
            'status': status
        })
        print(f"  {name}: ${cost:3d} ({status})")
    
    # Pick cheapest
    best = min(options, key=lambda x: x['cost'])
    best['route']['trucks'] += 1
    total_cost += best['cost']
    
    print(f"ASSIGN truck {truck_num}: {best['name']} route")

for name, route in routes.items():
    pct = (route['trucks'] / 15) * 100
    over_capacity = route['trucks'] - route['capacity']
    if route['trucks'] >= route['capacity'] * 2:
        status = f"CRITICAL ({over_capacity} over)"
    elif route['trucks'] >= route['capacity']:
        status = f"FULL ({over_capacity} over)"
    else:
        status = "OK"
    print(f"{name:5s}: {route['trucks']} trucks ({pct:.0f}%) - {status}")
print(f"\nTotal cost: ${total_cost}")
print(f"Average cost per truck: ${total_cost/30:.2f}")
# Out:
#   S98: $  7 (At/ less than Capacity)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 1: S98 route
#   S98: $  7 (At/ less than Capacity)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 2: S98 route
#   S98: $  7 (At/ less than Capacity)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 3: S98 route
#   S98: $  7 (At/ less than Capacity)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 4: S98 route
#   S98: $  7 (At/ less than Capacity)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 5: S98 route
#   S98: $  7 (At/ less than Capacity)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 6: S98 route
#   S98: $ 17 (Congested)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 7: I25 route
#   S98: $ 17 (Congested)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 8: I25 route
#   S98: $ 17 (Congested)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 9: I25 route
#   S98: $ 17 (Congested)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 10: I25 route
#   S98: $ 17 (Congested)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 11: I25 route
#   S98: $ 17 (Congested)
#   I25: $  8 (At/ less than Capacity)
# ASSIGN truck 12: I25 route
#   S98: $ 17 (Congested)
#   I25: $ 18 (Congested)
# ASSIGN truck 13: S98 route
#   S98: $ 17 (Congested)
#   I25: $ 18 (Congested)
# ASSIGN truck 14: S98 route
#   S98: $ 17 (Congested)
#   I25: $ 18 (Congested)
# ASSIGN truck 15: S98 route
#   S98: $ 17 (Congested)
#   I25: $ 18 (Congested)
# ASSIGN truck 16: S98 route
#   S98: $ 32 (FULL)
#   I25: $ 18 (Congested)
# ASSIGN truck 17: I25 route
#   S98: $ 32 (FULL)
#   I25: $ 18 (Congested)
# ASSIGN truck 18: I25 route
#   S98: $ 32 (FULL)
#   I25: $ 18 (Congested)
# ASSIGN truck 19: I25 route
# S98  : 10 trucks (67%) - CRITICAL (5 over)
# I25  : 9 trucks (60%) - FULL (4 over)
#
# Total cost: $212
# Average cost per truck: $7.07

# %% [markdown]
# ### Step 1: Simple Freeze and Assigning with discrete congestion cost pricing, trucks approaching from random distances and times

# %%
##### from dataclasses import dataclass
from typing import Optional
import random

#Create truck data class
@dataclass
class Truck:
    id: int
    name: str
    position: float  # Miles from ABQ
    speed: float     # MPH
    route: Optional[str] = None
    frozen: bool = False
    freeze_time: float = 0
    actual_cost: float = 0 


#Number of trucks? randomly 25 to 50 miles out and random speed between 50 and 70mph
def create_trucks(num_trucks):
    trucks = []
    for i in range(1, num_trucks + 1):
        truck = Truck(
            id=i,
            name=f"Truck {i}",
            position=random.randint(25, 50),  
            speed=random.randint(50, 70)     
        )
        trucks.append(truck)
    return trucks

#Time to ABQ 
def calculate_time_to_abq(truck):
    if truck.position <= 0:
        return 0
    return (truck.position / truck.speed) * 60 #in mins

def assign_route(truck, routes):
    S98 = routes['S98']
    I25 = routes['I25']
    
    #  cost for S98 route
    S98_cost = S98['cost']
    if S98['count'] >= S98['capacity']:
        S98_cost += 50  # Full
    elif S98['count'] >= S98['capacity'] * 0.8:
        S98_cost += 25   # Congested (80% full)
        
    #  cost for I25 route
    I25_cost = I25['cost']
    if I25['count'] >= I25['capacity']:
        I25_cost += 50  # Full - big penalty
    elif I25['count'] >= I25['capacity'] * 0.8:
        I25_cost += 25   # 80% full - medium penalty
    
    # Pick cheapest route
    if S98_cost <= I25_cost:
        truck.route = 'S98'
        S98['count'] += 1
        cost = S98_cost
    else:
        truck.route = 'I25'
        I25['count'] += 1
        cost = I25_cost
    
    return cost

#Interactive
num_trucks = int(input("\nHow many trucks? "))
trucks = create_trucks(num_trucks)

routes = {
    'S98': {'cost': 7, 'capacity': 5, 'count': 0},
    'I25': {'cost': 8, 'capacity': 5, 'count': 0}
}

#set freeze 15 mins from ABQ
freeze_horizon = 15

# initial positions
print("Initial positions:")
for truck in sorted(trucks, key=lambda t: t.position, reverse=True):
    time_to_abq = calculate_time_to_abq(truck)
    print(f"{truck.name}: {truck.position:.1f} mi, {truck.speed} mph & {time_to_abq:.1f} min to ABQ")
# Out:
# How many trucks?  30
# Initial positions:
# Truck 8: 47.0 mi, 69 mph & 40.9 min to ABQ
# Truck 7: 46.0 mi, 66 mph & 41.8 min to ABQ
# Truck 5: 45.0 mi, 66 mph & 40.9 min to ABQ
# Truck 15: 45.0 mi, 53 mph & 50.9 min to ABQ
# Truck 28: 45.0 mi, 59 mph & 45.8 min to ABQ
# Truck 10: 42.0 mi, 66 mph & 38.2 min to ABQ
# Truck 6: 41.0 mi, 61 mph & 40.3 min to ABQ
# Truck 11: 41.0 mi, 59 mph & 41.7 min to ABQ
# Truck 18: 40.0 mi, 68 mph & 35.3 min to ABQ
# Truck 30: 40.0 mi, 68 mph & 35.3 min to ABQ
# Truck 14: 38.0 mi, 68 mph & 33.5 min to ABQ
# Truck 21: 38.0 mi, 69 mph & 33.0 min to ABQ
# Truck 9: 37.0 mi, 67 mph & 33.1 min to ABQ
# Truck 13: 36.0 mi, 53 mph & 40.8 min to ABQ
# Truck 25: 36.0 mi, 59 mph & 36.6 min to ABQ
# Truck 26: 33.0 mi, 70 mph & 28.3 min to ABQ
# Truck 29: 33.0 mi, 51 mph & 38.8 min to ABQ
# Truck 1: 32.0 mi, 50 mph & 38.4 min to ABQ
# Truck 4: 30.0 mi, 68 mph & 26.5 min to ABQ
# Truck 16: 30.0 mi, 52 mph & 34.6 min to ABQ
# Truck 23: 30.0 mi, 51 mph & 35.3 min to ABQ
# Truck 20: 29.0 mi, 63 mph & 27.6 min to ABQ
# Truck 24: 29.0 mi, 67 mph & 26.0 min to ABQ
# Truck 17: 27.0 mi, 62 mph & 26.1 min to ABQ
# Truck 22: 27.0 mi, 54 mph & 30.0 min to ABQ
# Truck 27: 27.0 mi, 55 mph & 29.5 min to ABQ
# Truck 2: 26.0 mi, 53 mph & 29.4 min to ABQ
# Truck 3: 26.0 mi, 62 mph & 25.2 min to ABQ
# Truck 19: 26.0 mi, 67 mph & 23.3 min to ABQ
# Truck 12: 25.0 mi, 52 mph & 28.8 min to ABQ

# %%
# Main loop
time = 0
while any(not t.frozen for t in trucks):
    
    print(f"\n Time: {time} minutes")

    #Check for trucks at freeze horizon
    frozen_this_cycle=[]
    for truck in trucks:
        if not truck.frozen: 
            time_to_abq = calculate_time_to_abq(truck)

            if 0 < time_to_abq <= freeze_horizon:
                frozen_this_cycle.append((truck, time_to_abq))
    
    if frozen_this_cycle:
        print("Freeze Horizon Crossed")
        for truck, time_to_abq in frozen_this_cycle:
                    cost = assign_route(truck, routes)
                    truck.frozen = True
                    truck.freeze_time = time
                    truck.actual_cost = cost
                    
                    print(f"  {truck.name}:")
                    print(f"    Position: {truck.position:.1f} mi")
                    print(f"    Time to ABQ: {time_to_abq:.1f} min: Within 15 min")
                    print(f"    Assigned to {truck.route} route (${cost})")
    else:
        # Show status of active trucks
        active = [t for t in trucks if not t.frozen]
        if active:
            print(f"Active trucks (not at freeze horizon yet):")
            for truck in sorted(active, key=lambda t: calculate_time_to_abq(t)):
                time_to_abq = calculate_time_to_abq(truck)
                print(f"    {truck.name}: {truck.position:.1f} mi & {time_to_abq:.1f} min to ABQ")

    
#update position every 5 mins...    
    for truck in trucks:
        miles_traveled = (truck.speed / 60) * 5
        truck.position -= miles_traveled
        
    time += 5


print("\n End Results:")

total_S98_cost = sum(t.actual_cost for t in trucks if t.route == 'S98')
total_I25_cost = sum(t.actual_cost for t in trucks if t.route == 'I25')

print(f"S98: {routes['S98']['count']} trucks, total cost = ${total_S98_cost:.0f}")
print(f"I25: {routes['I25']['count']} trucks, total cost = ${total_I25_cost:.0f}")
print(f"\nOverall total cost: ${total_S98_cost + total_I25_cost:.0f}")
# Out:
#  Time: 0 minutes
# Active trucks (not at freeze horizon yet):
#     Truck 19: 26.0 mi & 23.3 min to ABQ
#     Truck 3: 26.0 mi & 25.2 min to ABQ
#     Truck 24: 29.0 mi & 26.0 min to ABQ
#     Truck 17: 27.0 mi & 26.1 min to ABQ
#     Truck 4: 30.0 mi & 26.5 min to ABQ
#     Truck 20: 29.0 mi & 27.6 min to ABQ
#     Truck 26: 33.0 mi & 28.3 min to ABQ
#     Truck 12: 25.0 mi & 28.8 min to ABQ
#     Truck 2: 26.0 mi & 29.4 min to ABQ
#     Truck 27: 27.0 mi & 29.5 min to ABQ
#     Truck 22: 27.0 mi & 30.0 min to ABQ
#     Truck 21: 38.0 mi & 33.0 min to ABQ
#     Truck 9: 37.0 mi & 33.1 min to ABQ
#     Truck 14: 38.0 mi & 33.5 min to ABQ
#     Truck 16: 30.0 mi & 34.6 min to ABQ
#     Truck 18: 40.0 mi & 35.3 min to ABQ
#     Truck 23: 30.0 mi & 35.3 min to ABQ
#     Truck 30: 40.0 mi & 35.3 min to ABQ
#     Truck 25: 36.0 mi & 36.6 min to ABQ
#     Truck 10: 42.0 mi & 38.2 min to ABQ
#     Truck 1: 32.0 mi & 38.4 min to ABQ
#     Truck 29: 33.0 mi & 38.8 min to ABQ
#     Truck 6: 41.0 mi & 40.3 min to ABQ
#     Truck 13: 36.0 mi & 40.8 min to ABQ
#     Truck 8: 47.0 mi & 40.9 min to ABQ
#     Truck 5: 45.0 mi & 40.9 min to ABQ
#     Truck 11: 41.0 mi & 41.7 min to ABQ
#     Truck 7: 46.0 mi & 41.8 min to ABQ
#     Truck 28: 45.0 mi & 45.8 min to ABQ
#     Truck 15: 45.0 mi & 50.9 min to ABQ
#
#  Time: 5 minutes
# Active trucks (not at freeze horizon yet):
#     Truck 19: 20.4 mi & 18.3 min to ABQ
#     Truck 3: 20.8 mi & 20.2 min to ABQ
#     Truck 24: 23.4 mi & 21.0 min to ABQ
#     Truck 17: 21.8 mi & 21.1 min to ABQ
#     Truck 4: 24.3 mi & 21.5 min to ABQ
#     Truck 20: 23.8 mi & 22.6 min to ABQ
#     Truck 26: 27.2 mi & 23.3 min to ABQ
#     Truck 12: 20.7 mi & 23.8 min to ABQ
#     Truck 2: 21.6 mi & 24.4 min to ABQ
#     Truck 27: 22.4 mi & 24.5 min to ABQ
#     Truck 22: 22.5 mi & 25.0 min to ABQ
#     Truck 21: 32.2 mi & 28.0 min to ABQ
#     Truck 9: 31.4 mi & 28.1 min to ABQ
#     Truck 14: 32.3 mi & 28.5 min to ABQ
#     Truck 16: 25.7 mi & 29.6 min to ABQ
#     Truck 18: 34.3 mi & 30.3 min to ABQ
#     Truck 23: 25.8 mi & 30.3 min to ABQ
#     Truck 30: 34.3 mi & 30.3 min to ABQ
#     Truck 25: 31.1 mi & 31.6 min to ABQ
#     Truck 10: 36.5 mi & 33.2 min to ABQ
#     Truck 1: 27.8 mi & 33.4 min to ABQ
#     Truck 29: 28.8 mi & 33.8 min to ABQ
#     Truck 6: 35.9 mi & 35.3 min to ABQ
#     Truck 13: 31.6 mi & 35.8 min to ABQ
#     Truck 8: 41.2 mi & 35.9 min to ABQ
#     Truck 5: 39.5 mi & 35.9 min to ABQ
#     Truck 11: 36.1 mi & 36.7 min to ABQ
#     Truck 7: 40.5 mi & 36.8 min to ABQ
#     Truck 28: 40.1 mi & 40.8 min to ABQ
#     Truck 15: 40.6 mi & 45.9 min to ABQ
#
#  Time: 10 minutes
# Freeze Horizon Crossed
#   Truck 19:
#     Position: 14.8 mi
#     Time to ABQ: 13.3 min: Within 15 min
#     Assigned to S98 route ($7)
#
#  Time: 15 minutes
# Freeze Horizon Crossed
#   Truck 2:
#     Position: 12.8 mi
#     Time to ABQ: 14.4 min: Within 15 min
#     Assigned to S98 route ($7)
#   Truck 3:
#     Position: 10.5 mi
#     Time to ABQ: 10.2 min: Within 15 min
#     Assigned to S98 route ($7)
#   Truck 4:
#     Position: 13.0 mi
#     Time to ABQ: 11.5 min: Within 15 min
#     Assigned to S98 route ($7)
#   Truck 12:
#     Position: 12.0 mi
#     Time to ABQ: 13.8 min: Within 15 min
#     Assigned to I25 route ($8)
#   Truck 17:
#     Position: 11.5 mi
#     Time to ABQ: 11.1 min: Within 15 min
#     Assigned to I25 route ($8)
#   Truck 20:
#     Position: 13.2 mi
#     Time to ABQ: 12.6 min: Within 15 min
#     Assigned to I25 route ($8)
#   Truck 22:
#     Position: 13.5 mi
#     Time to ABQ: 15.0 min: Within 15 min
#     Assigned to I25 route ($8)
#   Truck 24:
#     Position: 12.2 mi
#     Time to ABQ: 11.0 min: Within 15 min
#     Assigned to S98 route ($32)
#   Truck 26:
#     Position: 15.5 mi
#     Time to ABQ: 13.3 min: Within 15 min
#     Assigned to I25 route ($33)
#   Truck 27:
#     Position: 13.3 mi
#     Time to ABQ: 14.5 min: Within 15 min
#     Assigned to S98 route ($57)
#
#  Time: 20 minutes
# Freeze Horizon Crossed
#   Truck 9:
#     Position: 14.7 mi
#     Time to ABQ: 13.1 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 14:
#     Position: 15.3 mi
#     Time to ABQ: 13.5 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 16:
#     Position: 12.7 mi
#     Time to ABQ: 14.6 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 21:
#     Position: 15.0 mi
#     Time to ABQ: 13.0 min: Within 15 min
#     Assigned to S98 route ($57)
#
#  Time: 25 minutes
# Freeze Horizon Crossed
#   Truck 1:
#     Position: 11.2 mi
#     Time to ABQ: 13.4 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 10:
#     Position: 14.5 mi
#     Time to ABQ: 13.2 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 18:
#     Position: 11.7 mi
#     Time to ABQ: 10.3 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 23:
#     Position: 8.8 mi
#     Time to ABQ: 10.3 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 25:
#     Position: 11.4 mi
#     Time to ABQ: 11.6 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 29:
#     Position: 11.8 mi
#     Time to ABQ: 13.8 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 30:
#     Position: 11.7 mi
#     Time to ABQ: 10.3 min: Within 15 min
#     Assigned to S98 route ($57)
#
#  Time: 30 minutes
# Freeze Horizon Crossed
#   Truck 5:
#     Position: 12.0 mi
#     Time to ABQ: 10.9 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 6:
#     Position: 10.5 mi
#     Time to ABQ: 10.3 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 7:
#     Position: 13.0 mi
#     Time to ABQ: 11.8 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 8:
#     Position: 12.5 mi
#     Time to ABQ: 10.9 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 11:
#     Position: 11.5 mi
#     Time to ABQ: 11.7 min: Within 15 min
#     Assigned to S98 route ($57)
#   Truck 13:
#     Position: 9.5 mi
#     Time to ABQ: 10.8 min: Within 15 min
#     Assigned to S98 route ($57)
#
#  Time: 35 minutes
# Freeze Horizon Crossed
#   Truck 28:
#     Position: 10.6 mi
#     Time to ABQ: 10.8 min: Within 15 min
#     Assigned to S98 route ($57)
#
#  Time: 40 minutes
# Freeze Horizon Crossed
#   Truck 15:
#     Position: 9.7 mi
#     Time to ABQ: 10.9 min: Within 15 min
#     Assigned to S98 route ($57)
#
#  End Results:
# S98: 25 trucks, total cost = $1200
# I25: 5 trucks, total cost = $65
#
# Overall total cost: $1265

# %% [markdown]
# ### With BPR

# %%
import numpy as np

# %%
from dataclasses import dataclass
from typing import Optional
import random

#Create truck data class
@dataclass
class Truck:
    id: int
    name: str
    position: float  # Miles from ABQ
    speed: float     # MPH
    route: Optional[str] = None
    frozen: bool = False
    freeze_time: float = 0
    actual_cost: float = 0 


#Number of trucks? randomly 25 to 50 miles out and random speed between 50 and 70mph
def create_trucks(num_trucks):
    trucks = []
    for i in range(1, num_trucks + 1):
        truck = Truck(
            id=i,
            name=f"Truck {i}",
            position=random.randint(25, 50),  
            speed=random.randint(50, 70)     
        )
        trucks.append(truck)
    return trucks

#Time to ABQ 
def calculate_time_to_abq(truck):
    if truck.position <= 0:
        return 0
    return (truck.position / truck.speed) * 60 #in mins


def bpr_cost_function(Q, C, tf, alpha=0.15, beta=4):
    """
    Standard BPR cost function
    
    T = tf * [1 + α * (Q/C)^β]
    
    Parameters:
    - Q: traffic flow (current trucks on route)
    - C: capacity
    - tf: free-flow travel time
    - alpha: scale parameter (default 0.15)
    - beta: shape parameter (default 4)
    """
    vc_ratio = Q / C
    travel_time_bpr = tf * (1 + alpha * (vc_ratio ** beta))
    
    return travel_time_bpr
    
#assigning routes using BPR function
def assign_route(truck, routes, current_time):

    print(f"\n Evaluating routes for {truck.name}:")

    best_route = None
    best_cost = float('inf')

    for name, route in routes.items():
        Q = route['count']
        C = route['capacity']
        tf = route ['base_time']

        travel_time_bpr = bpr_cost_function(Q, C, tf)
    
        total_cost = travel_time_bpr + route['cost']
    
        # Print evaluation
        utilization = (Q / C) * 100
        print(f"    {name}:")
        print(f"      Flow: {Q}/{C} ({utilization:.0f}% capacity)")
        print(f"      Travel time: {travel_time_bpr:.1f} min")
        print(f"      Total cost: ${total_cost:.2f}")
        
        # Track best option
        if total_cost < best_cost:
            best_cost = total_cost
            best_route = name
        
    # Assign best route
    truck.route = best_route
    truck.actual_cost = best_cost
    routes[best_route]['count'] += 1
    
    print(f"Choose: {best_route} (${best_cost:.2f})")
    
    return best_cost

#Interactive
num_trucks = int(input("\nHow many trucks? "))
trucks = create_trucks(num_trucks)

# Routes with base travel times
routes = {
    'S98': {
        'cost': 7,
        'capacity': 5,
        'count': 0,
        'base_time': 32    # mins
    },
    'I25': {
        'cost': 8,
        'capacity': 5,
        'count': 0,
        'base_time': 35    
    }
}

freeze_horizon = 15.0
frozen_trucks = []


# initial positions
print("Initial positions:")
for truck in sorted(trucks, key=lambda t: t.position, reverse=True):
    time_to_abq = calculate_time_to_abq(truck)
    print(f"{truck.name}: {truck.position:.1f} mi, {truck.speed} mph & {time_to_abq:.1f} min to ABQ")
# Out:
# How many trucks?  30
# Initial positions:
# Truck 9: 46.0 mi, 59 mph & 46.8 min to ABQ
# Truck 14: 46.0 mi, 55 mph & 50.2 min to ABQ
# Truck 19: 46.0 mi, 61 mph & 45.2 min to ABQ
# Truck 5: 44.0 mi, 59 mph & 44.7 min to ABQ
# Truck 24: 44.0 mi, 70 mph & 37.7 min to ABQ
# Truck 25: 44.0 mi, 51 mph & 51.8 min to ABQ
# Truck 15: 42.0 mi, 54 mph & 46.7 min to ABQ
# Truck 18: 42.0 mi, 62 mph & 40.6 min to ABQ
# Truck 23: 42.0 mi, 53 mph & 47.5 min to ABQ
# Truck 2: 41.0 mi, 52 mph & 47.3 min to ABQ
# Truck 12: 41.0 mi, 54 mph & 45.6 min to ABQ
# Truck 22: 41.0 mi, 62 mph & 39.7 min to ABQ
# Truck 6: 38.0 mi, 70 mph & 32.6 min to ABQ
# Truck 4: 37.0 mi, 59 mph & 37.6 min to ABQ
# Truck 8: 37.0 mi, 50 mph & 44.4 min to ABQ
# Truck 1: 35.0 mi, 52 mph & 40.4 min to ABQ
# Truck 16: 33.0 mi, 56 mph & 35.4 min to ABQ
# Truck 3: 32.0 mi, 60 mph & 32.0 min to ABQ
# Truck 10: 32.0 mi, 56 mph & 34.3 min to ABQ
# Truck 17: 32.0 mi, 50 mph & 38.4 min to ABQ
# Truck 28: 32.0 mi, 60 mph & 32.0 min to ABQ
# Truck 11: 31.0 mi, 54 mph & 34.4 min to ABQ
# Truck 13: 29.0 mi, 61 mph & 28.5 min to ABQ
# Truck 21: 29.0 mi, 52 mph & 33.5 min to ABQ
# Truck 30: 29.0 mi, 64 mph & 27.2 min to ABQ
# Truck 29: 28.0 mi, 58 mph & 29.0 min to ABQ
# Truck 7: 27.0 mi, 53 mph & 30.6 min to ABQ
# Truck 20: 27.0 mi, 58 mph & 27.9 min to ABQ
# Truck 26: 27.0 mi, 70 mph & 23.1 min to ABQ
# Truck 27: 27.0 mi, 57 mph & 28.4 min to ABQ

# %%
# Main loop
time = 0
while any(not t.frozen for t in trucks):
    
    print(f"\n Time: {time} minutes")

    #Check for trucks at freeze horizon
    frozen_this_cycle=[]
    for truck in trucks:
        if not truck.frozen: 
            time_to_abq = calculate_time_to_abq(truck)

            if 0 < time_to_abq <= freeze_horizon:
                frozen_this_cycle.append((truck, time_to_abq))
    
    if frozen_this_cycle:
        print("Freeze Horizon Crossed")
        print(f"   {len(frozen_this_cycle)} truck(s) within 15 minutes of ABQ")
        print()
        for truck, time_to_abq in frozen_this_cycle:
            print(f"   {truck.name}: {time_to_abq:.1f} min to ABQ (≤ 15 min threshold)")
        for truck, time_to_abq in frozen_this_cycle:
                    cost = assign_route(truck, routes, time)
                    truck.frozen = True
                    truck.freeze_time = time
                    frozen_trucks.append(truck)

    else:
        # Show status of active trucks
        active = [t for t in trucks if not t.frozen]
        if active:
            print(f"Active trucks (not at freeze horizon yet):")
            for truck in sorted(active, key=lambda t: calculate_time_to_abq(t))[:3]:
                time_to_abq = calculate_time_to_abq(truck)
                print(f"    {truck.name}: {truck.position:.1f} mi & {time_to_abq:.1f} min to ABQ")

    
#update position every 5 mins...    
    for truck in trucks:
        miles_traveled = (truck.speed / 60) * 5
        truck.position -= miles_traveled
        
    time += 5


print("\n End Results:")

total_S98_cost = sum(t.actual_cost for t in trucks if t.route == 'S98')
total_I25_cost = sum(t.actual_cost for t in trucks if t.route == 'I25')

print(f"S98: {routes['S98']['count']} trucks, total cost = ${total_S98_cost:.0f}")
print(f"I25: {routes['I25']['count']} trucks, total cost = ${total_I25_cost:.0f}")
print(f"\nOverall total cost: ${total_S98_cost + total_I25_cost:.0f}")

# Show average costs
if routes['S98']['count'] > 0:
    avg_south = total_S98_cost / routes['S98']['count']
    print(f"Average cost per truck (S98): ${avg_south:.2f}")
if routes['I25']['count'] > 0:
    avg_north = total_I25_cost / routes['I25']['count']
    print(f"Average cost per truck (I25): ${avg_north:.2f}")
# Out:
#  Time: 0 minutes
# Active trucks (not at freeze horizon yet):
#     Truck 26: 27.0 mi & 23.1 min to ABQ
#     Truck 30: 29.0 mi & 27.2 min to ABQ
#     Truck 20: 27.0 mi & 27.9 min to ABQ
#
#  Time: 5 minutes
# Active trucks (not at freeze horizon yet):
#     Truck 26: 21.2 mi & 18.1 min to ABQ
#     Truck 30: 23.7 mi & 22.2 min to ABQ
#     Truck 20: 22.2 mi & 22.9 min to ABQ
#
#  Time: 10 minutes
# Freeze Horizon Crossed
#    1 truck(s) within 15 minutes of ABQ
#
#    Truck 26: 13.1 min to ABQ (≤ 15 min threshold)
#
#  Evaluating routes for Truck 26:
#     S98:
#       Flow: 0/5 (0% capacity)
#       Travel time: 32.0 min
#       Total cost: $39.00
#     I25:
#       Flow: 0/5 (0% capacity)
#       Travel time: 35.0 min
#       Total cost: $43.00
# Choose: S98 ($39.00)
#
#  Time: 15 minutes
# Freeze Horizon Crossed
#    5 truck(s) within 15 minutes of ABQ
#
#    Truck 13: 13.5 min to ABQ (≤ 15 min threshold)
#    Truck 20: 12.9 min to ABQ (≤ 15 min threshold)
#    Truck 27: 13.4 min to ABQ (≤ 15 min threshold)
#    Truck 29: 14.0 min to ABQ (≤ 15 min threshold)
#    Truck 30: 12.2 min to ABQ (≤ 15 min threshold)
#
#  Evaluating routes for Truck 13:
#     S98:
#       Flow: 1/5 (20% capacity)
#       Travel time: 32.0 min
#       Total cost: $39.01
#     I25:
#       Flow: 0/5 (0% capacity)
#       Travel time: 35.0 min
#       Total cost: $43.00
# Choose: S98 ($39.01)
#
#  Evaluating routes for Truck 20:
#     S98:
#       Flow: 2/5 (40% capacity)
#       Travel time: 32.1 min
#       Total cost: $39.12
#     I25:
#       Flow: 0/5 (0% capacity)
#       Travel time: 35.0 min
#       Total cost: $43.00
# Choose: S98 ($39.12)
#
#  Evaluating routes for Truck 27:
#     S98:
#       Flow: 3/5 (60% capacity)
#       Travel time: 32.6 min
#       Total cost: $39.62
#     I25:
#       Flow: 0/5 (0% capacity)
#       Travel time: 35.0 min
#       Total cost: $43.00
# Choose: S98 ($39.62)
#
#  Evaluating routes for Truck 29:
#     S98:
#       Flow: 4/5 (80% capacity)
#       Travel time: 34.0 min
#       Total cost: $40.97
#     I25:
#       Flow: 0/5 (0% capacity)
#       Travel time: 35.0 min
#       Total cost: $43.00
# Choose: S98 ($40.97)
#
#  Evaluating routes for Truck 30:
#     S98:
#       Flow: 5/5 (100% capacity)
#       Travel time: 36.8 min
#       Total cost: $43.80
#     I25:
#       Flow: 0/5 (0% capacity)
#       Travel time: 35.0 min
#       Total cost: $43.00
# Choose: I25 ($43.00)
#
#  Time: 20 minutes
# Freeze Horizon Crossed
#    7 truck(s) within 15 minutes of ABQ
#
#    Truck 3: 12.0 min to ABQ (≤ 15 min threshold)
#    Truck 6: 12.6 min to ABQ (≤ 15 min threshold)
#    Truck 7: 10.6 min to ABQ (≤ 15 min threshold)
#    Truck 10: 14.3 min to ABQ (≤ 15 min threshold)
#    Truck 11: 14.4 min to ABQ (≤ 15 min threshold)
#    Truck 21: 13.5 min to ABQ (≤ 15 min threshold)
#    Truck 28: 12.0 min to ABQ (≤ 15 min threshold)
#
#  Evaluating routes for Truck 3:
#     S98:
#       Flow: 5/5 (100% capacity)
#       Travel time: 36.8 min
#       Total cost: $43.80
#     I25:
#       Flow: 1/5 (20% capacity)
#       Travel time: 35.0 min
#       Total cost: $43.01
# Choose: I25 ($43.01)
#
#  Evaluating routes for Truck 6:
#     S98:
#       Flow: 5/5 (100% capacity)
#       Travel time: 36.8 min
#       Total cost: $43.80
#     I25:
#       Flow: 2/5 (40% capacity)
#       Travel time: 35.1 min
#       Total cost: $43.13
# Choose: I25 ($43.13)
#
#  Evaluating routes for Truck 7:
#     S98:
#       Flow: 5/5 (100% capacity)
#       Travel time: 36.8 min
#       Total cost: $43.80
#     I25:
#       Flow: 3/5 (60% capacity)
#       Travel time: 35.7 min
#       Total cost: $43.68
# Choose: I25 ($43.68)
#
#  Evaluating routes for Truck 10:
#     S98:
#       Flow: 5/5 (100% capacity)
#       Travel time: 36.8 min
#       Total cost: $43.80
#     I25:
#       Flow: 4/5 (80% capacity)
#       Travel time: 37.2 min
#       Total cost: $45.15
# Choose: S98 ($43.80)
#
#  Evaluating routes for Truck 11:
#     S98:
#       Flow: 6/5 (120% capacity)
#       Travel time: 42.0 min
#       Total cost: $48.95
#     I25:
#       Flow: 4/5 (80% capacity)
#       Travel time: 37.2 min
#       Total cost: $45.15
# Choose: I25 ($45.15)
#
#  Evaluating routes for Truck 21:
#     S98:
#       Flow: 6/5 (120% capacity)
#       Travel time: 42.0 min
#       Total cost: $48.95
#     I25:
#       Flow: 5/5 (100% capacity)
#       Travel time: 40.2 min
#       Total cost: $48.25
# Choose: I25 ($48.25)
#
#  Evaluating routes for Truck 28:
#     S98:
#       Flow: 6/5 (120% capacity)
#       Travel time: 42.0 min
#       Total cost: $48.95
#     I25:
#       Flow: 6/5 (120% capacity)
#       Travel time: 45.9 min
#       Total cost: $53.89
# Choose: S98 ($48.95)
#
#  Time: 25 minutes
# Freeze Horizon Crossed
#    5 truck(s) within 15 minutes of ABQ
#
#    Truck 4: 12.6 min to ABQ (≤ 15 min threshold)
#    Truck 16: 10.4 min to ABQ (≤ 15 min threshold)
#    Truck 17: 13.4 min to ABQ (≤ 15 min threshold)
#    Truck 22: 14.7 min to ABQ (≤ 15 min threshold)
#    Truck 24: 12.7 min to ABQ (≤ 15 min threshold)
#
#  Evaluating routes for Truck 4:
#     S98:
#       Flow: 7/5 (140% capacity)
#       Travel time: 50.4 min
#       Total cost: $57.44
#     I25:
#       Flow: 6/5 (120% capacity)
#       Travel time: 45.9 min
#       Total cost: $53.89
# Choose: I25 ($53.89)
#
#  Evaluating routes for Truck 16:
#     S98:
#       Flow: 7/5 (140% capacity)
#       Travel time: 50.4 min
#       Total cost: $57.44
#     I25:
#       Flow: 7/5 (140% capacity)
#       Travel time: 55.2 min
#       Total cost: $63.17
# Choose: S98 ($57.44)
#
#  Evaluating routes for Truck 17:
#     S98:
#       Flow: 8/5 (160% capacity)
#       Travel time: 63.5 min
#       Total cost: $70.46
#     I25:
#       Flow: 7/5 (140% capacity)
#       Travel time: 55.2 min
#       Total cost: $63.17
# Choose: I25 ($63.17)
#
#  Evaluating routes for Truck 22:
#     S98:
#       Flow: 8/5 (160% capacity)
#       Travel time: 63.5 min
#       Total cost: $70.46
#     I25:
#       Flow: 8/5 (160% capacity)
#       Travel time: 69.4 min
#       Total cost: $77.41
# Choose: S98 ($70.46)
#
#  Evaluating routes for Truck 24:
#     S98:
#       Flow: 9/5 (180% capacity)
#       Travel time: 82.4 min
#       Total cost: $89.39
#     I25:
#       Flow: 8/5 (160% capacity)
#       Travel time: 69.4 min
#       Total cost: $77.41
# Choose: I25 ($77.41)
#
#  Time: 30 minutes
# Freeze Horizon Crossed
#    4 truck(s) within 15 minutes of ABQ
#
#    Truck 1: 10.4 min to ABQ (≤ 15 min threshold)
#    Truck 5: 14.7 min to ABQ (≤ 15 min threshold)
#    Truck 8: 14.4 min to ABQ (≤ 15 min threshold)
#    Truck 18: 10.6 min to ABQ (≤ 15 min threshold)
#
#  Evaluating routes for Truck 1:
#     S98:
#       Flow: 9/5 (180% capacity)
#       Travel time: 82.4 min
#       Total cost: $89.39
#     I25:
#       Flow: 9/5 (180% capacity)
#       Travel time: 90.1 min
#       Total cost: $98.11
# Choose: S98 ($89.39)
#
#  Evaluating routes for Truck 5:
#     S98:
#       Flow: 10/5 (200% capacity)
#       Travel time: 108.8 min
#       Total cost: $115.80
#     I25:
#       Flow: 9/5 (180% capacity)
#       Travel time: 90.1 min
#       Total cost: $98.11
# Choose: I25 ($98.11)
#
#  Evaluating routes for Truck 8:
#     S98:
#       Flow: 10/5 (200% capacity)
#       Travel time: 108.8 min
#       Total cost: $115.80
#     I25:
#       Flow: 10/5 (200% capacity)
#       Travel time: 119.0 min
#       Total cost: $127.00
# Choose: S98 ($115.80)
#
#  Evaluating routes for Truck 18:
#     S98:
#       Flow: 11/5 (220% capacity)
#       Travel time: 144.4 min
#       Total cost: $151.44
#     I25:
#       Flow: 10/5 (200% capacity)
#       Travel time: 119.0 min
#       Total cost: $127.00
# Choose: I25 ($127.00)
#
#  Time: 35 minutes
# Freeze Horizon Crossed
#    6 truck(s) within 15 minutes of ABQ
#
#    Truck 2: 12.3 min to ABQ (≤ 15 min threshold)
#    Truck 9: 11.8 min to ABQ (≤ 15 min threshold)
#    Truck 12: 10.6 min to ABQ (≤ 15 min threshold)
#    Truck 15: 11.7 min to ABQ (≤ 15 min threshold)
#    Truck 19: 10.2 min to ABQ (≤ 15 min threshold)
#    Truck 23: 12.5 min to ABQ (≤ 15 min threshold)
#
#  Evaluating routes for Truck 2:
#     S98:
#       Flow: 11/5 (220% capacity)
#       Travel time: 144.4 min
#       Total cost: $151.44
#     I25:
#       Flow: 11/5 (220% capacity)
#       Travel time: 158.0 min
#       Total cost: $165.98
# Choose: S98 ($151.44)
#
#  Evaluating routes for Truck 9:
#     S98:
#       Flow: 12/5 (240% capacity)
#       Travel time: 191.3 min
#       Total cost: $198.25
#     I25:
#       Flow: 11/5 (220% capacity)
#       Travel time: 158.0 min
#       Total cost: $165.98
# Choose: I25 ($165.98)
#
#  Evaluating routes for Truck 12:
#     S98:
#       Flow: 12/5 (240% capacity)
#       Travel time: 191.3 min
#       Total cost: $198.25
#     I25:
#       Flow: 12/5 (240% capacity)
#       Travel time: 209.2 min
#       Total cost: $217.18
# Choose: S98 ($198.25)
#
#  Evaluating routes for Truck 15:
#     S98:
#       Flow: 13/5 (260% capacity)
#       Travel time: 251.3 min
#       Total cost: $258.35
#     I25:
#       Flow: 12/5 (240% capacity)
#       Travel time: 209.2 min
#       Total cost: $217.18
# Choose: I25 ($217.18)
#
#  Evaluating routes for Truck 19:
#     S98:
#       Flow: 13/5 (260% capacity)
#       Travel time: 251.3 min
#       Total cost: $258.35
#     I25:
#       Flow: 13/5 (260% capacity)
#       Travel time: 274.9 min
#       Total cost: $282.91
# Choose: S98 ($258.35)
#
#  Evaluating routes for Truck 23:
#     S98:
#       Flow: 14/5 (280% capacity)
#       Travel time: 327.0 min
#       Total cost: $334.03
#     I25:
#       Flow: 13/5 (260% capacity)
#       Travel time: 274.9 min
#       Total cost: $282.91
# Choose: I25 ($282.91)
#
#  Time: 40 minutes
# Freeze Horizon Crossed
#    2 truck(s) within 15 minutes of ABQ
#
#    Truck 14: 10.2 min to ABQ (≤ 15 min threshold)
#    Truck 25: 11.8 min to ABQ (≤ 15 min threshold)
#
#  Evaluating routes for Truck 14:
#     S98:
#       Flow: 14/5 (280% capacity)
#       Travel time: 327.0 min
#       Total cost: $334.03
#     I25:
#       Flow: 14/5 (280% capacity)
#       Travel time: 357.7 min
#       Total cost: $365.69
# Choose: S98 ($334.03)
#
#  Evaluating routes for Truck 25:
#     S98:
#       Flow: 15/5 (300% capacity)
#       Travel time: 420.8 min
#       Total cost: $427.80
#     I25:
#       Flow: 14/5 (280% capacity)
#       Travel time: 357.7 min
#       Total cost: $365.69
# Choose: I25 ($365.69)
#
#  End Results:
# S98: 15 trucks, total cost = $1566
# I25: 15 trucks, total cost = $1718
#
# Overall total cost: $3283
# Average cost per truck (S98): $104.38
# Average cost per truck (I25): $114.50

# %% [markdown]
# #### Step 2: Add trial options

# %% [markdown]
# #### Step 3: Add propogation

# %% [markdown]
# #### Step 4: Add delay distribution

# %% [markdown]
# Frank wolf
# BPR
# cost: monotonic increasing fucntion
# truck demand, routing
